# %% [markdown]
# # Introduction à Python — démo
#
# **Consigne 1** : exécute la cellule ci-dessous avec `Shift + Entrée`.

# %%
import pandas as pd

data = {
    "patient_id": [1, 2, 3, 4, 5],
    "age": [45, 62, 38, 71, 29],
    "tension": [130, 145, 118, 160, 122]
}
df = pd.DataFrame(data)
df

# %% [markdown]
# **Consigne 2** : calcule quelques statistiques descriptives.

# %%
df.describe()

# %% [markdown]
# **Consigne 3** : trace un histogramme des âges.

# %%
import matplotlib.pyplot as plt

df["age"].hist()
plt.xlabel("Âge")
plt.ylabel("Nombre de patients")
plt.title("Distribution des âges")
plt.show()
